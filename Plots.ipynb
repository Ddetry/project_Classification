# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import matplotlib.pyplot as plt

path = '/Users/damien/Documents/Sinf/2eme_bis/2eme_quadri/QDA/project_Classification/Select.csv'
my_db = pd.read_csv(path, sep=';')

my_db['Passed'].plot()
my_db['guardian'].plot()
my_db['age'].plot()

Passed = my_db.Passed[my_db["Passed"]== 1].count()
plt.show()
Passed
# Out:
# 265

# %%
import matplotlib.pyplot as plt

x = my_db['guardian']
y = my_db['age']
plt.plot(x, y)
plt.title("test")
plt.axis('equal')
plt.xlabel("guardian")
plt.ylabel("Passed")
plt.show()

# %%
fig = plt.figure()

x = my_db['age']
Passed = my_db.Passed[my_db["Passed"]== 1]
height = Passed
width = 1.0

plt.bar(x, height, width, color='b' )

plt.savefig('SimpleBar.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-234caa80346d> in <module>()
#       6 width = 1.0
#       7
# ----> 8 plt.bar(x, height, width, color='b' )
#       9
#      10 plt.savefig('SimpleBar.png')
#
# /Users/damien/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2703     try:
#    2704         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2705                      **kwargs)
#    2706     finally:
#    2707         ax._hold = washold
#
# /Users/damien/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/damien/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2077         if len(height) != nbars:
#    2078             raise ValueError("incompatible sizes: argument 'height' "
# -> 2079                               "must be length %d or scalar" % nbars)
#    2080         if len(width) != nbars:
#    2081             raise ValueError("incompatible sizes: argument 'width' "
#
# ValueError: incompatible sizes: argument 'height' must be length 395 or scalar
