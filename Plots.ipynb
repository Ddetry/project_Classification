# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import matplotlib.pyplot as plt

path = '/Users/damien/Documents/Sinf/2eme_bis/2eme_quadri/QDA/project_Classification/Select.csv'
my_db = pd.read_csv(path, sep=';')

my_db['Passed'].plot()


Passed = my_db.Passed[my_db["Passed"]== 1].count()
plt.show()
Passed
# Out:
# 265

# %%
import matplotlib.pyplot as plt

x = my_db['guardian']
y = my_db['age']
plt.plot(x, y)
plt.title("test")
plt.axis('equal')
plt.xlabel("guardian")
plt.ylabel("Passed")
plt.show()

# %%
print(my_db.columns.values)
# Out:
# ['guardian' 'failures' 'schoolsup' 'paid' 'higher' 'romantic' 'goout' 'age'
#  'Passed']
